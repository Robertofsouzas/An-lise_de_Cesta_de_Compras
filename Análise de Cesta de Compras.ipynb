# %% [markdown]
# #  Market Basket Analysis

# %% [markdown]
# # O Que é MBA (Market Basket Analysis)?
#
# A Análise de Cesta de Compras (Market Basket Analysis) é uma das principais técnicas usadas por grandes varejistas para descobrir associações entre itens. A técnica funciona procurando combinações de itens que ocorrem juntos com frequência nas transações. Em outras palavras, permite que os varejistas identifiquem as relações entre os itens que as pessoas compram.
#
# A Análise de Cesta de Compras emprega algoritmos de regras de associação, que são amplamente utilizadas para analisar cesta de varejo ou dados de transação e têm o objetivo de identificar regras fortes descobertas em dados de transações comerciais usando medidas de interesse, com base no conceito de regras fortes.

# %%
# https://pypi.org/project/efficient-apriori/
# !pip install -q efficient_apriori
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from itertools import combinations
import efficient_apriori
from efficient_apriori import apriori

# %% [markdown]
# ## 1- Carregando os Dados

# %%
aisle = pd.read_csv('C:/Users/ROBERTO/Downloads/Projeto_Analise_CestaCompras/dados/aisles.csv')
departments = pd.read_csv('C:/Users/ROBERTO/Downloads/Projeto_Analise_CestaCompras/dados/departments.csv')
order_products__prior = pd.read_csv('C:/Users/ROBERTO/Downloads/Projeto_Analise_CestaCompras/dados/order_products__prior.csv')
order_products__train = pd.read_csv('C:/Users/ROBERTO/Downloads/Projeto_Analise_CestaCompras/dados/order_products__train.csv')
orders = pd.read_csv('C:/Users/ROBERTO/Downloads/Projeto_Analise_CestaCompras/dados/orders.csv')
products = pd.read_csv('C:/Users/ROBERTO/Downloads/Projeto_Analise_CestaCompras/dados/products.csv')

# %% [markdown]
# # 2 - Análise Exploratória

# %% [markdown]
# > Faz sentido calcular a correlação com colunas do tipo ID ?

# %%
aisle.shape
# Out:
# (134, 2)

# %%
aisle.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
departments.shape
# Out:
# (21, 2)

# %%
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
products.shape
# Out:
# (49688, 4)

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
orders.shape
# Out:
# (3421083, 7)

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_products__prior.shape
# Out:
# (32434489, 4)

# %%
order_products__prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_products__train.shape
# Out:
# (1384617, 4)

# %%
order_products__prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %% [markdown]
# > Por que não usar programação  e verificar o total de registros em todos os datasets de uma vez?

# %%
# Total de Registros por Dataset
                  
count_array = np.array([['Aisles', len(aisle)],
                       ['Departament', len(departments)],
                       ['Product',len(products)],
                       ['order',len(orders)],
                       ['Order_Product_Prior',len(order_products__prior)],
                       ['Order_Product_train',len(order_products__train)]])
count_record= pd.DataFrame(count_array,columns= ['Arquivo','Total de Registros'])
count_record
# Out:
#                Arquivo Total de Registros
# 0               Aisles                134
# 1          Departament                 21
# 2              Product              49688
# 3                order            3421083
# 4  Order_Product_Prior           32434489
# 5  Order_Product_train            1384617

# %%
 # Total de Itens nas categorias de eval_set
orders['eval_set'].value_counts()
# Out:
# prior    3214874
# train     131209
# test       75000
# Name: eval_set, dtype: int64

# %% [markdown]
# # 3 - Limpeza dos Dados
#
# ### Verificando Valores Ausentes

# %%
aisle.isna().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
departments.isna().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
orders.isna().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
products.isna().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
order_products__prior.isna().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
order_products__train.isna().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %% [markdown]
# # Feature Extraction
#
# ### Merge da tabela order_product_prior com order,product,aisle e departament

# %%
# Merge
order_products__prior=order_products__prior.merge(orders, on = 'order_id', how ='left')
order_products__prior=order_products__prior.merge(products, on = 'product_id', how ='left')
order_products__prior=order_products__prior.merge(aisle, on = 'aisle_id', how ='left')
order_products__prior=order_products__prior.merge(departments, on = 'department_id', how ='left')

# %%
order_products__prior.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1         2       28985                  2          1   202279    prior
# 2         2        9327                  3          0   202279    prior
# 3         2       45918                  4          1   202279    prior
# 4         2       30035                  5          0   202279    prior
# 5         2       17794                  6          1   202279    prior
# 6         2       40141                  7          1   202279    prior
# 7         2        1819                  8          1   202279    prior
# 8         2       43668                  9          0   202279    prior
# 9         3       33754                  1          1   205970    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             3          5                  9                     8.0
# 1             3          5                  9                     8.0
# 2             3          5                  9                     8.0
# 3             3          5                  9                     8.0
# 4             3          5                  9                     8.0
# 5             3          5                  9                     8.0
# 6             3          5                  9                     8.0
# 7             3          5                  9                     8.0
# 8             3          5                  9                     8.0
# 9            16          5                 17                    12.0
#
#                                         product_name  aisle_id  department_id  \
# 0                                 Organic Egg Whites        86             16
# 1                              Michigan Organic Kale        83              4
# 2                                      Garlic Powder       104             13
# 3                                     Coconut Butter        19             13
# 4                                  Natural Sweetener        17             13
# 5                                            Carrots        83              4
# 6                   Original Unflavored Gelatine Mix       105             13
# 7           All Natural No Stir Creamy Almond Butter        88             13
# 8                            Classic Blend Cole Slaw       123              4
# 9  Total 2% with Strawberry Lowfat Greek Strained...       120             16
#
#                         aisle  department
# 0                        eggs  dairy eggs
# 1            fresh vegetables     produce
# 2           spices seasonings      pantry
# 3               oils vinegars      pantry
# 4          baking ingredients      pantry
# 5            fresh vegetables     produce
# 6  doughs gelatins bake mixes      pantry
# 7                     spreads      pantry
# 8  packaged vegetables fruits     produce
# 9                      yogurt  dairy eggs

# %%
order_products__prior.shape
# Out:
# (32434489, 15)

# %%
order_products__prior.isna().sum()
# Out:
# order_id                        0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# user_id                         0
# eval_set                        0
# order_number                    0
# order_dow                       0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_name                    0
# aisle_id                        0
# department_id                   0
# aisle                           0
# department                      0
# dtype: int64

# %%
percentage = order_products__prior.isna().sum() / len(order_products__prior) *100
percentage_com2casas= round(percentage,2)
percentage_com2casas
# Out:
# order_id                  0.00
# product_id                0.00
# add_to_cart_order         0.00
# reordered                 0.00
# user_id                   0.00
# eval_set                  0.00
# order_number              0.00
# order_dow                 0.00
# order_hour_of_day         0.00
# days_since_prior_order    6.41
# product_name              0.00
# aisle_id                  0.00
# department_id             0.00
# aisle                     0.00
# department                0.00
# dtype: float64

# %% [markdown]
# Vamos manter a variável days_since_prior_order por duas razões:
#
# 1- O percentual de valores ausentes é apenas de 6.4%.
#
# 2- Não usaremos a variável com o algoritmo MBA.

# %% [markdown]
# ### Merge da Tabela Order_product_train com order, product, aisle e department

# %%
# %%time
order_products__train= order_products__train.merge(orders, on= 'order_id', how = 'left')
order_products__train= order_products__train.merge(products, on= 'product_id', how = 'left')
order_products__train= order_products__train.merge(aisle, on= 'aisle_id', how = 'left')
order_products__train= order_products__train.merge(departments, on= 'department_id', how = 'left')
# Out:
# Wall time: 4.76 s

# %%
order_products__train.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         1       49302                  1          1   112108    train
# 1         1       11109                  2          1   112108    train
# 2         1       10246                  3          0   112108    train
# 3         1       49683                  4          0   112108    train
# 4         1       43633                  5          1   112108    train
# 5         1       13176                  6          0   112108    train
# 6         1       47209                  7          0   112108    train
# 7         1       22035                  8          1   112108    train
# 8        36       39612                  1          0    79431    train
# 9        36       19660                  2          1    79431    train
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0             4          4                 10                     9.0
# 1             4          4                 10                     9.0
# 2             4          4                 10                     9.0
# 3             4          4                 10                     9.0
# 4             4          4                 10                     9.0
# 5             4          4                 10                     9.0
# 6             4          4                 10                     9.0
# 7             4          4                 10                     9.0
# 8            23          6                 18                    30.0
# 9            23          6                 18                    30.0
#
#                                     product_name  aisle_id  department_id  \
# 0                               Bulgarian Yogurt       120             16
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2                          Organic Celery Hearts        83              4
# 3                                 Cucumber Kirby        83              4
# 4           Lightly Smoked Sardines in Olive Oil        95             15
# 5                         Bag of Organic Bananas        24              4
# 6                           Organic Hass Avocado        24              4
# 7                    Organic Whole String Cheese        21             16
# 8                  Grated Pecorino Romano Cheese         2             16
# 9                                   Spring Water       115              7
#
#                            aisle    department
# 0                         yogurt    dairy eggs
# 1           other creams cheeses    dairy eggs
# 2               fresh vegetables       produce
# 3               fresh vegetables       produce
# 4            canned meat seafood  canned goods
# 5                   fresh fruits       produce
# 6                   fresh fruits       produce
# 7                packaged cheese    dairy eggs
# 8              specialty cheeses    dairy eggs
# 9  water seltzer sparkling water     beverages

# %%
order_products__train.isna().sum()
# Out:
# order_id                  0
# product_id                0
# add_to_cart_order         0
# reordered                 0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# product_name              0
# aisle_id                  0
# department_id             0
# aisle                     0
# department                0
# dtype: int64

# %% [markdown]
# > Vamos agrupar os dados para aplicar o algaritimo Apriori e Preparar o dataset com todas as transações

# %%
# %%time
order_grouped= pd.DataFrame(order_products__prior.groupby('order_id')['product_id'])
# Out:
# Wall time: 7min 37s

# %%
order_grouped.shape
# Out:
# (3214874, 2)

# %%
len(order_grouped[0])
# Out:
# 3214874

# %%
order_grouped.head()
# Out:
#    0                                                  1
# 0  2  0    33120
# 1    28985
# 2     9327
# 3    45918
# 4 ...
# 1  3  9     33754
# 10    24838
# 11    17704
# 12    2190...
# 2  4  17    46842
# 18    26434
# 19    39758
# 20    2776...
# 3  5  30    13176
# 31    15005
# 32    47329
# 33    2796...
# 4  6  56    40462
# 57    15873
# 58    41897
# Name: prod...

# %%
# Listas
prod=[]

# %%
# %%time
for i in range(len(order_grouped[0])):
    prod.append(list(order_grouped.iloc[i][1]))
# Out:
# Wall time: 21min 17s

# %%
prod_=prod

# %%
order_ = order_grouped[0]

# %%
# Prepara o DataFrame

transactions = pd.DataFrame({'OrderID':order_, 'Products': prod_})

# %%
transactions.head(10)
# Out:
#    OrderID                                           Products
# 0        2  [33120, 28985, 9327, 45918, 30035, 17794, 4014...
# 1        3  [33754, 24838, 17704, 21903, 17668, 46667, 174...
# 2        4  [46842, 26434, 39758, 27761, 10054, 21351, 225...
# 3        5  [13176, 15005, 47329, 27966, 23909, 48370, 132...
# 4        6                              [40462, 15873, 41897]
# 5        7                                     [34050, 46802]
# 6        8                                            [23423]
# 7        9  [21405, 47890, 11182, 2014, 29193, 34203, 1499...
# 8       10  [24852, 4796, 31717, 47766, 4605, 1529, 21137,...
# 9       11                  [30162, 27085, 5994, 1313, 31506]

# %% [markdown]
# ## Análise Estatística Descretiva
#
# ### 1 - Qual o número de pedidos mais frequente entre os usuários?

# %%
# Agrupa os dados por usuário e número do pedido, agregando pelo maior valor

ord_max_count = orders.groupby('user_id')['order_number'].aggregate(np.max).reset_index() 
ord_max_count.head()
# Out:
#    user_id  order_number
# 0        1            11
# 1        2            15
# 2        3            13
# 3        4             6
# 4        5             5

# %%
# Faz a contagem por número de pedidos
ord_max_count = ord_max_count.order_number.value_counts()
ord_max_count.head()
# Out:
# 4    23986
# 5    19590
# 6    16165
# 7    13850
# 8    11700
# Name: order_number, dtype: int64

# %%
# Plot
plt.style.use('ggplot')
plt.figure(figsize = (20,8))
plt.bar(ord_max_count.index, ord_max_count.values, color = 'indigo', width = 0.6)
plt.xticks(ord_max_count.index, rotation = 'vertical')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.xlabel('Número de Pedidos Mais Frequente Entre os Usuários', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## 2 - Qual Dia da semana tem o maior númerode pedidos ?

# %%
# Frequencia de pedidos por dia da semana(dow = day of week)
x = [0,1,2,3,4,5,6]
y = [orders[orders['order_dow']==0].shape[0],
    orders[orders['order_dow']==1].shape[0],
    orders[orders['order_dow']==2].shape[0],
    orders[orders['order_dow']==3].shape[0],
    orders[orders['order_dow']==4].shape[0],
    orders[orders['order_dow']==5].shape[0],
    orders[orders['order_dow']==6].shape[0] ]

# %%
# Plot
plt.figure(figsize = (10,5))
plt.bar(x,y, color = 'slateblue')
plt.xlabel('Dia da Semana', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.xticks(x,['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado'], rotation = 'vertical')
plt.show()

# %% [markdown]
# ## 3 - Qual hora do dia tem maior número de pedidos?

# %%
# Frenquencia de pedidos pela hora do dia
x = list(range(0,24))
y= []
for i in range(24):
    y.append(orders[orders['order_hour_of_day']==i].shape[0])

# %%
# Plot
plt.figure(figsize = (20,5))
plt.bar(x,y,color = 'forestgreen')
plt.xticks(np.arange(0,24,1))
plt.xlabel('Hora do Dia', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## 4 - Qual departamento tem o maior número de pedidos?

# %%
# Contagem de pedidos por departamento
dept_cnt = order_products__prior['department'].value_counts()
dept_cnt
# Out:
# produce            9479291
# dairy eggs         5414016
# snacks             2887550
# beverages          2690129
# frozen             2236432
# pantry             1875577
# bakery             1176787
# canned goods       1068058
# deli               1051249
# dry goods pasta     866627
# household           738666
# breakfast           709569
# meat seafood        708931
# personal care       447123
# babies              423802
# international       269253
# alcohol             153696
# pets                 97724
# missing              69145
# other                36291
# bulk                 34573
# Name: department, dtype: int64

# %%
# Plot

fig = plt.figure(figsize=(20,10))
dept_cnt.plot(kind='bar', color='purple')
plt.xticks(rotation =90)
plt.xlabel('Departamento', fontsize =14, fontweight='bold')
plt.ylabel('Frequência', fontsize=14, fontweight= 'bold')
plt.show()

# %% [markdown]
# ## 5 - Quais os 20 principais Corredores por frenquência de pedidos?

# %%
# os 20 principais corredores e sua frenquência de pedidos
aisle_cnt = order_products__prior['aisle'].value_counts()
aisle_cnt
# Out:
# fresh fruits                  3642188
# fresh vegetables              3418021
# packaged vegetables fruits    1765313
# yogurt                        1452343
# packaged cheese                979763
#                                ...
# eye ear care                     8974
# baby bath body care              8581
# baby accessories                 8160
# beauty                           6168
# frozen juice                     4853
# Name: aisle, Length: 134, dtype: int64

# %%
# Plot
fig = plt.figure(figsize = (20,10))
aisle_cnt[0:20].plot(kind = "bar", color = 'darkgoldenrod')
plt.xticks(rotation = 90)
plt.xlabel('Corredor', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## 6 - Quais os 20 principais Produtos por Frenquência de pedidos?

# %%
prod_cnt_df = order_products__prior['product_name'].value_counts()
prod_cnt_df
# Out:
# Banana                         472565
# Bag of Organic Bananas         379450
# Organic Strawberries           264683
# Organic Baby Spinach           241921
# Organic Hass Avocado           213584
#                                 ...
# Frittata, Farmer's Market           1
# Fig Balsamic Vinegar                1
# Punjabi Chhole, Hot Spicy           1
# Molasses, Bead                      1
# Flatbread Pizza All Natural         1
# Name: product_name, Length: 49677, dtype: int64

# %%
# Plot
fig = plt.figure(figsize = (20,10))
prod_cnt_df[0:20].plot(kind = "bar", color = 'purple')
plt.xticks(rotation = 90)
plt.xlabel('Produto', fontsize = 14, fontweight = 'bold')
plt.ylabel('Frequência', fontsize = 14, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## 7 - Análise de novos pedidos semelhantes a pedidos anteriores(reorder)

# %%
# %%time
temp_df = order_products__prior.groupby('product_name')['reordered'].agg(['count','sum']).rename(columns={'count': 'Total','sum':'reorders'})
temp_df= temp_df.sort_values('Total',ascending=False).reset_index()
# Out:
# Wall time: 24.1 s

# %%
# Prepara as listas
labels = list(temp_df.product_name[0:20])
reorder = list(temp_df.reorders[0:20])
total = list(temp_df.Total[0:20])

# %%
# Plot  
width = 0.35 
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(labels, reorder, width, label = 'Reorder', color = 'green')
ax.bar(labels, total, width, bottom = reorder, label = 'Total', color = 'red')
ax.set_ylabel('Total de Pedidos', fontsize = 14, fontweight = 'bold')
ax.legend()
ax.set_title("Produtos Mais Populares")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## 7 - Análise de reorder por departamento ao longo do tempo

# %%
# Agrupando os dados por departamento e reorder
grouped_df = order_products__prior.groupby(['department'])['reordered'].aggregate('mean').reset_index()

# %%
# Plot
plt.figure(figsize = (12,8))
plt.plot(list(grouped_df['department']), grouped_df['reordered'].values, alpha=0.8)
plt.scatter(list(grouped_df['department']), grouped_df['reordered'].values)
plt.ylabel('Taxa de Reorder', fontsize = 12)
plt.xlabel('Departmento', fontsize = 12)
plt.title("Departmento x Taxa de Reorder", fontsize = 15)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### 8- Análise de Reorder e Pedidos

# %%
# %%time
temp_df = order_products__prior.groupby("department")["reordered"].agg(['count', 'sum']).rename(columns = {'count':'total','sum':'reorders'})
temp_df = temp_df.sort_values('total', ascending = False).reset_index()
# Out:
# Wall time: 3.95 s

# %%
temp_df.head()
# Out:
#    department    total  reorders
# 0     produce  9479291   6160710
# 1  dairy eggs  5414016   3627221
# 2      snacks  2887550   1657973
# 3   beverages  2690129   1757892
# 4      frozen  2236432   1211890

# %%
# Listas
labels = list(temp_df.department[0:20])
reorder = list(temp_df.reorders[0:20])
total = list(temp_df.total[0:20])

# %%
# Plot
width = 0.35  
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(labels, reorder, width, label = 'Reorder', color = 'magenta')
ax.bar(labels, total, width, bottom = reorder, label = 'Pedidos', color = 'blue')
ax.set_ylabel('Total de Pedidos', fontsize = 14, fontweight = 'bold')
ax.legend()
ax.set_title("Total de Pedidos e Reorders dos Departmentos")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### 9- Análise de Reorder Por Corredor

# %%
grouped_df = order_products__prior.groupby(["aisle"])["reordered"].aggregate("mean").reset_index()
grouped_df.head()
# Out:
#                     aisle  reordered
# 0  air fresheners candles   0.309052
# 1             asian foods   0.351132
# 2        baby accessories   0.550980
# 3     baby bath body care   0.295770
# 4       baby food formula   0.590259

# %%
list(grouped_df['aisle'])[0:20]
# Out:
# ['air fresheners candles',
#  'asian foods',
#  'baby accessories',
#  'baby bath body care',
#  'baby food formula',
#  'bakery desserts',
#  'baking ingredients',
#  'baking supplies decor',
#  'beauty',
#  'beers coolers',
#  'body lotions soap',
#  'bread',
#  'breakfast bakery',
#  'breakfast bars pastries',
#  'bulk dried fruits vegetables',
#  'bulk grains rice dried goods',
#  'buns rolls',
#  'butter',
#  'candy chocolate',
#  'canned fruit applesauce']

# %%
# Corredor x Taxa de Reorder
plt.figure(figsize=(14,7))
plt.plot(list(grouped_df['aisle'])[0:20], grouped_df['reordered'].values[0:20], alpha=0.8)
plt.scatter(list(grouped_df['aisle'])[0:20], grouped_df['reordered'].values[0:20])
plt.ylabel('Taxa de Reorder', fontsize=12)
plt.xlabel('Corredor', fontsize=12)
plt.title("Corredor x Taxa de Reorder", fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
#  ### 10- Análise de Reorder Por Corredor (Total)

# %%
# %%time
temp_df = order_products__prior.groupby("aisle")["reordered"].agg(['count', 'sum']).rename(columns = {'count':'total','sum':'reorders'})
temp_df = temp_df.sort_values('total', ascending = False).reset_index()
# Out:
# Wall time: 4.63 s

# %%
temp_df.head()
# Out:
#                         aisle    total  reorders
# 0                fresh fruits  3642188   2615469
# 1            fresh vegetables  3418021   2032172
# 2  packaged vegetables fruits  1765313   1127177
# 3                      yogurt  1452343    997018
# 4             packaged cheese   979763    573383

# %%
# Listas
labels = list(temp_df.aisle[0:20])
reorder = list(temp_df.reorders[0:20])
total = list(temp_df.total[0:20])

# %%
# Plot
width = 0.35      
fig, ax = plt.subplots(figsize = (20,10))
ax.bar(labels, reorder, width, label = 'Reorder', color = 'green')
ax.bar(labels, total, width, bottom = reorder, label = 'Total', color = 'red')
ax.set_ylabel('Total de Pedidos', fontsize = 14, fontweight = 'bold')
ax.legend()
ax.set_title("Total de Pedidos e Reorders dos Corredores")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# > Vamos verificar a relação entre como a ordem de adição do produto ao carrinho afeta a proporção de novos pedidos

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install -q shutup
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import shutup; shutup.please()

# %%
order_products__prior["add_to_cart_order_mod"] = order_products__prior["add_to_cart_order"].copy()
order_products__prior["add_to_cart_order_mod"].loc[order_products__prior["add_to_cart_order_mod"] > 70] = 70
grouped_df = order_products__prior.groupby(["add_to_cart_order_mod"])["reordered"].aggregate("mean").reset_index()

# %%
grouped_df.head(10)
# Out:
#    add_to_cart_order_mod  reordered
# 0                      1   0.677533
# 1                      2   0.676251
# 2                      3   0.658037
# 3                      4   0.636958
# 4                      5   0.617383
# 5                      6   0.600420
# 6                      7   0.585687
# 7                      8   0.573247
# 8                      9   0.561474
# 9                     10   0.551018

# %% [markdown]
# ## Implementação do Algoritmo Apriori

# %% [markdown]
# ##### Métricas: ![regras.png](attachment:regras.png)

# %% [markdown]
# Support = Fração de transações que contêm A e B.
#
# ![support.png](attachment:support.png)

# %% [markdown]
# Confidence = A frequência com que B aparece em transações que contêm apenas A.
#
# ![confidence.png](attachment:confidence.png)

# %% [markdown]
# Lift = Quanto aumentou nossa confiança de que B será comprado, dado que A foi comprado.
# ![lift.png](attachment:lift.png)

# %%
# Prepara a tupla com as transações
transactions_tup = [tuple(row) for row in transactions['Products'].tolist()]

# %% [markdown]
#  ### Executa o Algoritmo Apriori Com Support = 0.01 e Confidence = 0.2

# %%
st = datetime.now()
itemsets_ap, rules_ap = apriori(transactions_tup[:500000], min_support = 0.01, min_confidence = 0.2)
print('Tempo de Execução : ', datetime.now() - st)
# Out:
# Tempo de Execução :  0:00:14.056018

# %%
rules_ap
# Out:
# [{21137} -> {13176},
#  {21903} -> {13176},
#  {27966} -> {13176},
#  {47209} -> {13176},
#  {16797} -> {24852},
#  {21137} -> {24852},
#  {27966} -> {21137},
#  {21903} -> {24852},
#  {28204} -> {24852},
#  {47626} -> {24852},
#  {47766} -> {24852},
#  {49683} -> {24852}]

# %%
# Listas de itens para considerar
item_A = [27966,47209,21137,47766,21903,49683,47626,28204,16797,21903,21137,27966]
item_B = [13176,13176,24852,24852,24852,24852,24852,24852,24852,13176,13176,21137]
temp = pd.DataFrame()
temp['itemA'] = item_A
temp['itemB'] = item_B

# %%
# Listas para as métricas
support_A = []
support_B = []
support_AB = []
confidence_AB = []
lift_AB = []

# %%
# Loop
for i in range(len(temp)):
    
    # Calcula o support de A
    support_A.append(itemsets_ap[1][tuple([temp['itemA'][i],])] / 500000)
    
    # Calcula o support de B
    support_B.append(itemsets_ap[1][tuple([temp['itemB'][i],])] / 500000)
    
    # Calcula o support de A e B
    if tuple([temp['itemA'][i],temp['itemB'][i]]) in itemsets_ap[2].keys():
        support_AB.append(itemsets_ap[2][tuple([temp['itemA'][i],temp['itemB'][i]])] / 500000)
    else:
        support_AB.append(itemsets_ap[2][tuple([temp['itemB'][i],temp['itemA'][i]])] / 500000)
    
    # Calcula a confidence
    confidence_AB.append(support_AB[i] / support_A[i])
    
    # Calcula o lift
    lift_AB.append(support_AB[i] / (support_A[i] * support_B[i]))

# %%
# Dataframe com as regras de associação
df_rules_ap = pd.DataFrame()
df_rules_ap['product_id'] = item_A
df_rules_ap = df_rules_ap.merge(products, on = 'product_id', how = 'left')
df_rules_ap['Product_A'] = df_rules_ap['product_name']
df_rules_ap = df_rules_ap.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap['product_id'] = item_B
df_rules_ap = df_rules_ap.merge(products, on = 'product_id', how = 'left')
df_rules_ap['Product_B'] = df_rules_ap['product_name']
df_rules_ap = df_rules_ap.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap['Support_A'] = support_A
df_rules_ap['Support_B'] = support_B
df_rules_ap['Support_AB'] = support_AB
df_rules_ap['Confidence_AB'] = confidence_AB
df_rules_ap['Lift_AB'] = lift_AB

# %%
df_rules_ap.sort_values(by = 'Confidence_AB', ascending = False)
# Out:
#                Product_A               Product_B  Support_A  Support_B  \
# 7     Organic Fuji Apple                  Banana   0.027942   0.147194
# 5         Cucumber Kirby                  Banana   0.030218   0.147194
# 3        Organic Avocado                  Banana   0.054564   0.147194
# 0    Organic Raspberries  Bag of Organic Bananas   0.042334   0.117802
# 1   Organic Hass Avocado  Bag of Organic Bananas   0.066218   0.117802
# 8           Strawberries                  Banana   0.044496   0.147194
# 6            Large Lemon                  Banana   0.047718   0.147194
# 11   Organic Raspberries    Organic Strawberries   0.042334   0.082550
# 10  Organic Strawberries  Bag of Organic Bananas   0.082550   0.117802
# 4   Organic Baby Spinach                  Banana   0.075000   0.147194
# 2   Organic Strawberries                  Banana   0.082550   0.147194
# 9   Organic Baby Spinach  Bag of Organic Bananas   0.075000   0.117802
#
#     Support_AB  Confidence_AB   Lift_AB
# 7     0.010630       0.380431  2.584554
# 5     0.010024       0.331723  2.253644
# 3     0.016328       0.299245  2.032997
# 0     0.012428       0.293570  2.492064
# 1     0.019260       0.290857  2.469037
# 8     0.012902       0.289959  1.969908
# 6     0.012692       0.265979  1.806998
# 11    0.010524       0.248595  3.011442
# 10    0.019122       0.231641  1.966362
# 4     0.016016       0.213547  1.450784
# 2     0.017596       0.213156  1.448127
# 9     0.015500       0.206667  1.754356

# %%
df_rules_ap.sort_values(by = 'Lift_AB', ascending = False)
# Out:
#                Product_A               Product_B  Support_A  Support_B  \
# 11   Organic Raspberries    Organic Strawberries   0.042334   0.082550
# 7     Organic Fuji Apple                  Banana   0.027942   0.147194
# 0    Organic Raspberries  Bag of Organic Bananas   0.042334   0.117802
# 1   Organic Hass Avocado  Bag of Organic Bananas   0.066218   0.117802
# 5         Cucumber Kirby                  Banana   0.030218   0.147194
# 3        Organic Avocado                  Banana   0.054564   0.147194
# 8           Strawberries                  Banana   0.044496   0.147194
# 10  Organic Strawberries  Bag of Organic Bananas   0.082550   0.117802
# 6            Large Lemon                  Banana   0.047718   0.147194
# 9   Organic Baby Spinach  Bag of Organic Bananas   0.075000   0.117802
# 4   Organic Baby Spinach                  Banana   0.075000   0.147194
# 2   Organic Strawberries                  Banana   0.082550   0.147194
#
#     Support_AB  Confidence_AB   Lift_AB
# 11    0.010524       0.248595  3.011442
# 7     0.010630       0.380431  2.584554
# 0     0.012428       0.293570  2.492064
# 1     0.019260       0.290857  2.469037
# 5     0.010024       0.331723  2.253644
# 3     0.016328       0.299245  2.032997
# 8     0.012902       0.289959  1.969908
# 10    0.019122       0.231641  1.966362
# 6     0.012692       0.265979  1.806998
# 9     0.015500       0.206667  1.754356
# 4     0.016016       0.213547  1.450784
# 2     0.017596       0.213156  1.448127

# %% [markdown]
# ### Executa o Algoritmo Apriori Com Support = 0.005 e Confidence = 0.2

# %%
st = datetime.now()
itemsets_ap_1, rules_ap_1 = apriori(transactions_tup[:500000], min_support = 0.005, min_confidence = 0.2)
print('Tempo de Execução: ', datetime.now() - st)
# Out:
# Tempo de Execução:  0:00:15.553999

# %%
rules_ap_1
# Out:
# [{4605} -> {24852},
#  {4920} -> {24852},
#  {5876} -> {13176},
#  {5876} -> {47209},
#  {8277} -> {13176},
#  {8277} -> {24852},
#  {9076} -> {24852},
#  {19057} -> {13176},
#  {21137} -> {13176},
#  {21903} -> {13176},
#  {22935} -> {13176},
#  {27966} -> {13176},
#  {30391} -> {13176},
#  {37646} -> {13176},
#  {39275} -> {13176},
#  {45007} -> {13176},
#  {47209} -> {13176},
#  {16797} -> {24852},
#  {21137} -> {24852},
#  {27966} -> {21137},
#  {30391} -> {21137},
#  {39275} -> {21137},
#  {21903} -> {24852},
#  {24964} -> {22935},
#  {26209} -> {24852},
#  {27845} -> {24852},
#  {28204} -> {24852},
#  {30489} -> {24852},
#  {37646} -> {24852},
#  {40706} -> {24852},
#  {42265} -> {24852},
#  {44632} -> {24852},
#  {45066} -> {24852},
#  {47626} -> {24852},
#  {47766} -> {24852},
#  {49683} -> {24852},
#  {31717} -> {26209},
#  {30391} -> {47209}]

# %%
# Lista de itens para considerar
item_A1 = [27966,47209,4605,21137,47766,21903,49683,5876,37646,40706,47626,5876,30391,22935,37646,31717,
           28204,27845,24964,45066,9076,16797,21903,8277,30391,21137,27966,19057,26209,45007,39275,30489,
           42265,30391,8277,4920,39275,44632]
item_B1 = [13176,13176,24852,24852,24852,24852,24852,47209,24852,24852,24852,13176,13176,13176,13176,26209,
           24852,24852,22935,24852,24852,24852,13176,24852,47209,13176,21137,13176,24852,13176,21137,24852,
           24852,21137,13176,24852,13176,24852]
temp1 = pd.DataFrame()
temp1['itemA'] = item_A1
temp1['itemB'] = item_B1

# %%
# Listas de métricas
support_A1 = []
support_B1 = []
support_AB1 = []
confidence_AB1 = []
lift_AB1 = []

# %%
# Loop
for i in range(len(temp1)):
    
    support_A1.append(itemsets_ap_1[1][tuple([temp1['itemA'][i],])] / 500000)
    
    support_B1.append(itemsets_ap_1[1][tuple([temp1['itemB'][i],])] / 500000)
    
    if tuple([temp1['itemA'][i],temp1['itemB'][i]]) in itemsets_ap_1[2].keys():
        support_AB1.append(itemsets_ap_1[2][tuple([temp1['itemA'][i],temp1['itemB'][i]])] / 500000)
    else:
        support_AB1.append(itemsets_ap_1[2][tuple([temp1['itemB'][i],temp1['itemA'][i]])] / 500000)
    
    confidence_AB1.append(support_AB1[i] / support_A1[i])
    
    lift_AB1.append(support_AB1[i] / (support_A1[i] * support_B1[i]))

# %%
# Dataframe com as regras de associação
df_rules_ap1 = pd.DataFrame()
df_rules_ap1['product_id'] = item_A1
df_rules_ap1 = df_rules_ap1.merge(products, on = 'product_id', how = 'left')
df_rules_ap1['Product_A'] = df_rules_ap1['product_name']
df_rules_ap1 = df_rules_ap1.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap1['product_id'] = item_B1
df_rules_ap1 = df_rules_ap1.merge(products, on = 'product_id', how = 'left')
df_rules_ap1['Product_B'] = df_rules_ap1['product_name']
df_rules_ap1 = df_rules_ap1.drop(columns = ['product_id','product_name','aisle_id','department_id'], axis = 1)
df_rules_ap1['Support_A'] = support_A1
df_rules_ap1['Support_B'] = support_B1
df_rules_ap1['Support_AB'] = support_AB1
df_rules_ap1['Confidence_AB'] = confidence_AB1
df_rules_ap1['Lift_AB'] = lift_AB1

# %%
df_rules_ap1.sort_values(by = 'Confidence_AB', ascending = False).head(10)
# Out:
#                                Product_A               Product_B  Support_A  \
# 16                    Organic Fuji Apple                  Banana   0.027942
# 19                      Honeycrisp Apple                  Banana   0.024774
# 6                         Cucumber Kirby                  Banana   0.030218
# 27  Organic Large Extra Fancy Fuji Apple  Bag of Organic Bananas   0.023374
# 4                        Organic Avocado                  Banana   0.054564
# 35                   Seedless Red Grapes                  Banana   0.026054
# 2                          Yellow Onions                  Banana   0.022814
# 0                    Organic Raspberries  Bag of Organic Bananas   0.042334
# 20                           Blueberries                  Banana   0.017674
# 1                   Organic Hass Avocado  Bag of Organic Bananas   0.066218
#
#     Support_B  Support_AB  Confidence_AB   Lift_AB
# 16   0.147194    0.010630       0.380431  2.584554
# 19   0.147194    0.008832       0.356503  2.421993
# 6    0.147194    0.010024       0.331723  2.253644
# 27   0.117802    0.007330       0.313596  2.662063
# 4    0.147194    0.016328       0.299245  2.032997
# 35   0.147194    0.007750       0.297459  2.020864
# 2    0.147194    0.006750       0.295871  2.010075
# 0    0.117802    0.012428       0.293570  2.492064
# 20   0.147194    0.005186       0.293425  1.993460
# 1    0.117802    0.019260       0.290857  2.469037

# %%
df_rules_ap1.sort_values(by = 'Lift_AB', ascending = False).head(10)
# Out:
#                                Product_A               Product_B  Support_A  \
# 15                      Organic Cilantro                   Limes   0.021334
# 18                        Organic Garlic    Organic Yellow Onion   0.034158
# 7                          Organic Lemon    Organic Hass Avocado   0.027242
# 24                      Organic Cucumber    Organic Hass Avocado   0.025056
# 26                   Organic Raspberries    Organic Strawberries   0.042334
# 30                   Organic Blueberries    Organic Strawberries   0.031188
# 27  Organic Large Extra Fancy Fuji Apple  Bag of Organic Bananas   0.023374
# 16                    Organic Fuji Apple                  Banana   0.027942
# 0                    Organic Raspberries  Bag of Organic Bananas   0.042334
# 33                      Organic Cucumber    Organic Strawberries   0.025056
#
#     Support_B  Support_AB  Confidence_AB   Lift_AB
# 15   0.043640    0.005342       0.250398  5.737819
# 18   0.035306    0.006868       0.201066  5.694942
# 7    0.066218    0.006534       0.239850  3.622130
# 24   0.066218    0.005396       0.215358  3.252252
# 26   0.082550    0.010524       0.248595  3.011442
# 30   0.082550    0.007284       0.233551  2.829211
# 27   0.117802    0.007330       0.313596  2.662063
# 16   0.147194    0.010630       0.380431  2.584554
# 0    0.117802    0.012428       0.293570  2.492064
# 33   0.082550    0.005138       0.205061  2.484078

# %% [markdown]
# ## Conclusão
#
# Aplicando Matemática e Estatística via programação executamos uma análise de MBA gerando como resultado as regras de associação entre os produtos com diferentes métricas. Podemos agora levar nossas conclusões aos tomadores de decisão e partir para o próximo projeto.
